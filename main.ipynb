# %%
from src.pseudo_hilbert_curve import PseudoPeanoHilbertCurve
from src.snake_curve import SnakeCurve
from src.curve_utils.dimension import Dimension
from src.curve_utils.plot_utils import plot_curve

# %%
height = 5
width = 5
dim = Dimension(width, height)
num_el = width * height

curve = PseudoPeanoHilbertCurve(num_el, dim, 0, False)

plot_curve(num_el, curve, linewidth=2)

# %%
height = 6
width = 6
dim = Dimension(width, height)
num_el = width * height

curve1 = PseudoPeanoHilbertCurve(num_el, dim, 0)
curve2 = PseudoPeanoHilbertCurve(num_el, dim, 1)
curve3 = PseudoPeanoHilbertCurve(num_el, dim, 2)
curve4 = PseudoPeanoHilbertCurve(num_el, dim, 3)

plot_curve(num_el, curve1)

# %%
class Pessoa:
    def __init__(self, nome):
        self.nome = nome

pessoas = [
    Pessoa("João"),
    Pessoa("Maria"),
    Pessoa("José"),
    Pessoa("Ana"),
]

for pessoa in pessoas:
    pessoa.nome = pessoa.nome.upper()

for pessoa in pessoas:
    print(pessoa.nome)
# Out:
# JOÃO
# MARIA
# JOSÉ
# ANA
